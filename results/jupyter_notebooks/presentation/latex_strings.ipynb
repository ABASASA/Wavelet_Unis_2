# %%
import pathlib as pl

# %%
# iso

# %%
print('\\begin{onlyenv}'+'<{}-{}> \n'.format(1,1) +
    '\\begin{center}\n\
\t \\begin{figure} \n\
\t \\begin{centering} \n\
\t\t \\includegraphics[width=11cm]{'
+'images/0'.format(i) +
'} \\par \n \t \\end{centering} \n\
\\centering{}\\caption{Iso splits} \n \t \
\\end{figure} \\par \n \t \
\\end{center}\n \
\\end{onlyenv}')

for i in range(1,7):
    print('\\begin{onlyenv}'+'<{}-{}> \n'.format(i+1,i+1) +
    '\\begin{center}\n\
\t \\begin{figure} \n\
\t \\begin{centering} \n\
\t\t \\includegraphics[width=11cm]{'
+'images/iso/{}'.format(i) +
'} \\par \n \t \\end{centering} \n\
\\centering{}\\caption{Iso splits} \n \t \
\\end{figure} \\par \n \t \
\\end{center}\n \
\\end{onlyenv}')

# 2means
prevI = 8
print()
print('\\begin{onlyenv}'+'<{}-{}> \n'.format(prevI,prevI) +
    '\\begin{center}\n\
\t \\begin{figure} \n\
\t \\begin{centering} \n\
\t\t \\includegraphics[width=11cm]{'
+'images/0'.format(i) +
'} \\par \n \t \\end{centering} \n\
\\centering{}\\caption{2Means} \n \t \
\\end{figure} \\par \n \t \
\\end{center}\n \
\\end{onlyenv}')

for i in range(1,4):
    print('\\begin{onlyenv}'+'<{}-{}> \n'.format(i+prevI,i+prevI) +
    '\\begin{center}\n\
\t \\begin{figure} \n\
\t \\begin{centering} \n\
\t\t \\includegraphics[width=11cm]{'
+'images/2means/{}'.format(i) +
'} \\par \n \t \\end{centering} \n\
\\centering{}\\caption{2Means split} \n \t \
\\end{figure} \\par \n \t \
\\end{center}\n \
\\end{onlyenv}')
    
# PCA

prevI=12
print()
print('\\begin{onlyenv}'+'<{}-{}> \n'.format(prevI,prevI) +
    '\\begin{center}\n\
\t \\begin{figure} \n\
\t \\begin{centering} \n\
\t\t \\includegraphics[width=11cm]{'
+'images/0'.format(i) +
'} \\par \n \t \\end{centering} \n\
\\centering{}\\caption{PCA} \n \t \
\\end{figure} \\par \n \t \
\\end{center}\n \
\\end{onlyenv}')

for i in range(1,7):
    print('\\begin{onlyenv}'+'<{}-{}> \n'.format(i+prevI,i+prevI) +
    '\\begin{center}\n\
\t \\begin{figure} \n\
\t \\begin{centering} \n\
\t\t \\includegraphics[width=11cm]{'
+'images/pca/{}'.format(i) +
'} \\par \n \t \\end{centering} \n\
\\centering{}\\caption{PCA} \n \t \
\\end{figure} \\par \n \t \
\\end{center}\n \
\\end{onlyenv}')
    
#pls
print()
prevI=19

print('\\begin{onlyenv}'+'<{}-{}> \n'.format(prevI,prevI) +
    '\\begin{center}\n\
\t \\begin{figure} \n\
\t \\begin{centering} \n\
\t\t \\includegraphics[width=11cm]{'
+'images/0'.format(i) +
'} \\par \n \t \\end{centering} \n\
\\centering{}\\caption{pls \\textbf{NotImplementedError}} \n \t \
\\end{figure} \\par \n \t \
\\end{center}\n \
\\end{onlyenv}')

for i in range(1,5):
    print('\\begin{onlyenv}'+'<{}-{}> \n'.format(i+prevI,i+prevI) +
    '\\begin{center}\n\
\t \\begin{figure} \n\
\t \\begin{centering} \n\
\t\t \\includegraphics[width=11cm]{'
+'images/pca/{}'.format(i) +
'} \\par \n \t \\end{centering} \n\
\\centering{}\\caption{pls \\textbf{NotImplementedError}} \n \t \
\\end{figure} \\par \n \t \
\\end{center}\n \
\\end{onlyenv}')
# Out:
# \begin{onlyenv}<1-1>
# \begin{center}
# 	 \begin{figure}
# 	 \begin{centering}
# 		 \includegraphics[width=11cm]{images/0} \par
#  	 \end{centering}
# \centering{}\caption{Iso splits}
#  	 \end{figure} \par
#  	 \end{center}
#  \end{onlyenv}
# \begin{onlyenv}<2-2>
# \begin{center}
# 	 \begin{figure}
# 	 \begin{centering}
# 		 \includegraphics[width=11cm]{images/iso/1} \par
#  	 \end{centering}
# \centering{}\caption{Iso splits}
#  	 \end{figure} \par
#  	 \end{center}
#  \end{onlyenv}
# \begin{onlyenv}<3-3>
# \begin{center}
# 	 \begin{figure}
# 	 \begin{centering}
# 		 \includegraphics[width=11cm]{images/iso/2} \par
#  	 \end{centering}
# \centering{}\caption{Iso splits}
#  	 \end{figure} \par
#  	 \end{center}
#  \end{onlyenv}
# \begin{onlyenv}<4-4>
# \begin{center}
# 	 \begin{figure}
# 	 \begin{centering}
# 		 \includegraphics[width=11cm]{images/iso/3} \par
#  	 \end{centering}
# \centering{}\caption{Iso splits}
#  	 \end{figure} \par
#  	 \end{center}
#  \end{onlyenv}
# ...
